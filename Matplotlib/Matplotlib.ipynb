# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
ageList=[10,20,30,40,50,60,70,80,90,50,30]

# %%
weightList=[234,65,23,67,12,87,45,34,23,74,16]

# %%
numpyAgeList=np.array(ageList)

# %%
numpyWeightList=np.array(weightList)

# %%
numpyAgeList
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90, 50, 30])

# %%
numpyWeightList
# Out:
# array([234,  65,  23,  67,  12,  87,  45,  34,  23,  74,  16])

# %%
plt.plot(numpyAgeList,numpyWeightList,"b")
plt.xlabel("Age")
plt.ylabel("Weight")
plt.title("graph of weight change by age")
plt.show()

# %%
numpyArray1=np.linspace(0,10,20)

# %%
numpyArray1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyArray2=numpyArray1**3

# %%
numpyArray2
# Out:
# array([0.00000000e+00, 1.45793847e-01, 1.16635078e+00, 3.93643388e+00,
#        9.33080624e+00, 1.82242309e+01, 3.14914711e+01, 5.00072897e+01,
#        7.46464499e+01, 1.06283715e+02, 1.45793847e+02, 1.94051611e+02,
#        2.51931768e+02, 3.20309083e+02, 4.00058318e+02, 4.92054235e+02,
#        5.97171599e+02, 7.16285173e+02, 8.50269719e+02, 1.00000000e+03])

# %%
plt.plot(numpyArray1,numpyArray2,"g--")
plt.show()

# %%
plt.plot(numpyArray2,numpyArray1,"r*-")
plt.show()

# %%
plt.subplot(1,2,1)# 1 row , 2 column , 1st graphic
plt.plot(numpyArray1,numpyArray2,"r*-")
plt.subplot(1,2,2) # 1 row , 2 column , 2nd graphic
plt.plot(numpyArray2,numpayArray1,"g--")
plt.show()

# %%
myFigure=plt.figure()

# %%
figureAxes=myFigure.add_axes([0.1,0.1,0.3,0.3])
figureAxes.plot(numpayArray1,numpyArray2,"b")
figureAxes.set_xlabel("X Axis Data Name")
figureAxes.set_ylabel("Y Axis Data Name")
figureAxes.set_title("Grapgh Title")
plt.show()

# %%
figure2=plt.figure()

# %%
axis1=figure2.add_axes([0.1,0.1,0.8,0.8])
axis2=figure2.add_axes([0.3,0.4,0.3,0.3])

axis1.plot(numpyArray1,numpyArray2,"g")
axis1.set_xlabel("X Axis")
axis1.set_ylabel("Y Axis")
axis1.set_title("Main Graph Title")

axis2.plot(numpyArray2,numpyArray1,"b")
axis2.set_xlabel("X Axis - tiny")
axis2.set_ylabel("Y Axis - tiny")
axis2.set_title("Tiny Graph Title")

plt.show()

# %%
(myFigure,myAxis)=plt.subplots(nrows=1,ncols=2)
##myAxis.plot(numpyArray1,numpyArray2)
for axis in myAxis:
    axis.plot(numpyArray1,numpyArray2,"g")
    axis.set_xlabel("X Axis")
    axis.set_xlabel("Y Axis")


plt.tight_layout()

plt.show()

# %%
newFigure=plt.Figure(figsize=(13,5),dpi=100)

# %%
newAxis=newFigure.add_axes([0.1,0.1,0.9,0.9])
newAxis.plot(numpyArray1,numpyArray1**2, label="numpyArray **  2")
newAxis.plot(numpyArray1,numpyArray1**3, label="numpyArray **  3")

newAxis.legend(loc=1)

# %%
newFigure

# %%
newFigure.savefig("myFigure.png",dpi=400)
